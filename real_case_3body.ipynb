# %%
import bilby
import pandas as pd
import numpy as np
import corner
import matplotlib.pyplot as plt
import astropy.units as u
from astropy.cosmology import Planck15, z_at_value
import h5py

# %%
# Desktop

result11 = bilby.result.read_in_result(filename='./results_202308072154/GW150914_3/GW150914_result.json')#1000 
result12 = bilby.result.read_in_result(filename='./results_202308072154/GW150914_13/GW150914_result.json')#1000 
result13 = bilby.result.read_in_result(filename='./results_202308072154/GW150914_32/GW150914_result.json')#1000 
result14 = bilby.result.read_in_result(filename='./results_202308072154/GW150914_52/GW150914_result.json')#1000 
result15 = bilby.result.read_in_result(filename='./results_202308072154/GW150914_52/GW150914_result.json')#1000 

bilby.core.result.plot_multiple([result11, result12, result13, result14, result15], 
                          parameters = ["mass_1_source", "mass_2_source", "luminosity_distance"],
                                labels = ['1', '2','3', '4','5'],
#                                 evidences=True,
                                bins=50, 
                                smooth=0.9, 
                                label_kwargs=dict(fontsize=12),
                                show_titles=True,    
                                title_kwargs=dict(fontsize=12), 
#                                 color='#0072C1',
#                                 truth_color='tab:orange', 
                                quantiles=[0.05, 0.95],
            #                     levels=(1 - np.exp(-0.5), 1 - np.exp(-2), 1 - np.exp(-9 / 2.)),
                                levels=(0.5,0.9),
                                plot_density=False, 
                                plot_datapoints=False, 
                                fill_contours=False,
                                max_n_ticks=3, hist_kwargs=dict(density=True), truths = [ None])

# %%
# Group Server

result11 = bilby.result.read_in_result(filename='./results_202308081744/GW150914_17/GW150914_result.json')#1000 
result12 = bilby.result.read_in_result(filename='./results_202308081744/GW150914_46/GW150914_result.json')#1000 
result13 = bilby.result.read_in_result(filename='./results_202308081744/GW150914_51/GW150914_result.json')#1000 
result14 = bilby.result.read_in_result(filename='./results_202308081744/GW150914_68/GW150914_result.json')#1000 
result15 = bilby.result.read_in_result(filename='./results_202308081744/GW150914_90/GW150914_result.json')#1000 



bilby.core.result.plot_multiple([result11, result12, result13, result14, result15], 
                          parameters = ["mass_1_source", "mass_2_source", "luminosity_distance"],
                                labels = ['1', '2','3', '4','5'],
#                                 evidences=True,
                                bins=50, 
                                smooth=0.9, 
                                label_kwargs=dict(fontsize=12),
                                show_titles=True,    
                                title_kwargs=dict(fontsize=12), 
#                                 color='#0072C1',
#                                 truth_color='tab:orange', 
                                quantiles=[0.05, 0.95],
#                                 quantiles=[0.16, 0.84],
            #                     levels=(1 - np.exp(-0.5), 1 - np.exp(-2), 1 - np.exp(-9 / 2.)),
                                levels=(0.5,0.9),
                                plot_density=False, 
                                plot_datapoints=False, 
                                fill_contours=False,
                                max_n_ticks=3, hist_kwargs=dict(density=True), truths = [ None])

# %%
# Group Server

result11 = bilby.result.read_in_result(filename='./results_202308082121/GW150914_4/GW150914_result.json')#1000 
result12 = bilby.result.read_in_result(filename='./results_202308082121/GW150914_14/GW150914_result.json')#1000 
result13 = bilby.result.read_in_result(filename='./results_202308082121/GW150914_25/GW150914_result.json')#1000 
result14 = bilby.result.read_in_result(filename='./results_202308082121/GW150914_35/GW150914_result.json')#1000 
result15 = bilby.result.read_in_result(filename='./results_202308082121/GW150914_37/GW150914_result.json')#1000 



bilby.core.result.plot_multiple([result11, result12, result13, result14, result15], 
                          parameters = ["mass_1_source", "mass_2_source", "luminosity_distance", 'v_p'],
                                labels = ['1', '2','3', '4','5'],
#                                 evidences=True,
                                bins=50, 
                                smooth=0.9, 
                                label_kwargs=dict(fontsize=12),
                                show_titles=True,    
                                title_kwargs=dict(fontsize=12), 
#                                 color='#0072C1',
#                                 truth_color='tab:orange', 
                                quantiles=[0.05, 0.95],
#                                 quantiles=[0.16, 0.84],
            #                     levels=(1 - np.exp(-0.5), 1 - np.exp(-2), 1 - np.exp(-9 / 2.)),
                                levels=(0.5,0.9),
                                plot_density=False, 
                                plot_datapoints=False, 
                                fill_contours=False,
                                max_n_ticks=3, hist_kwargs=dict(density=True), truths = [ None])

# %%
# Group Server
path = "/run/user/1000/gvfs/sftp:host=119.78.226.66/home/ysc/Documents/PE_3body/results_202308092234/GW150914_"

result11 = bilby.result.read_in_result(filename = path + '35' + '/GW150914_result.json')#1000 
result12 = bilby.result.read_in_result(filename = path + '63' + '/GW150914_result.json')#1000 
result13 = bilby.result.read_in_result(filename = path + '84' + '/GW150914_result.json')#1000 
result14 = bilby.result.read_in_result(filename = path + '85' + '/GW150914_result.json')#1000 
result15 = bilby.result.read_in_result(filename = path + '99' + '/GW150914_result.json' )#1000 

bilby.core.result.plot_multiple([result11, result12, result13, result14, result15], 
                          parameters = ["mass_1_source", "mass_2_source", "luminosity_distance"],
                                labels = ['1', '2','3', '4','5'],
#                                 evidences=True,
                                bins=50, 
                                smooth=0.9, 
                                label_kwargs=dict(fontsize=12),
                                show_titles=True,    
                                title_kwargs=dict(fontsize=12), 
#                                 color='#0072C1',
#                                 truth_color='tab:orange', 
                                quantiles=[0.05, 0.95],
#                                 quantiles=[0.16, 0.84],
            #                     levels=(1 - np.exp(-0.5), 1 - np.exp(-2), 1 - np.exp(-9 / 2.)),
                                levels=(0.5,0.9),
                                plot_density=True, 
                                plot_datapoints=False, 
                                fill_contours=False,
                                max_n_ticks=3, hist_kwargs=dict(density=True), truths = [ None])

# %%
result_list =  bilby.core.result.ResultList([result11, result12, result13, result14, result15])
result_all = result_list.combine()

bilby.core.result.plot_multiple([result_all], 
                          parameters = ["mass_1_source", "mass_2_source", "luminosity_distance"],
                                labels = ['combined'],
#                                 evidences=True,
                                bins=50, 
                                smooth=0.9, 
                                label_kwargs=dict(fontsize=12),
                                show_titles=True,    
                                title_kwargs=dict(fontsize=12), 
#                                 color='#0072C1',
#                                 truth_color='tab:orange', 
                                quantiles=[0.05, 0.95],
#                                 quantiles=[0.16, 0.84],
            #                     levels=(1 - np.exp(-0.5), 1 - np.exp(-2), 1 - np.exp(-9 / 2.)),
                                levels=(0.5,0.9),
                                plot_density=True, 
                                plot_datapoints=False, 
                                fill_contours=False,
                                max_n_ticks=3, hist_kwargs=dict(density=True), truths = [ None])

# result11.save_to_file(filename= 'test.hdf5', overwrite=True, outdir='.', extension='hdf5')
# Out:
# 10:32 bilby INFO    : Combined results have 75037 samples

# %%
# Group Server
path = "/run/user/1000/gvfs/sftp:host=119.78.226.66/home/ysc/Documents/PE_3body/results_202308100831/GW150914_"

result11 = bilby.result.read_in_result(filename = path + '17' + '/GW150914_result.json')#1000 
result12 = bilby.result.read_in_result(filename = path + '40' + '/GW150914_result.json')#1000 
result13 = bilby.result.read_in_result(filename = path + '56' + '/GW150914_result.json')#1000 
result14 = bilby.result.read_in_result(filename = path + '77' + '/GW150914_result.json')#1000 
result15 = bilby.result.read_in_result(filename = path + '98' + '/GW150914_result.json' )#1000 

bilby.core.result.plot_multiple([result11, result12, result13, result14, result15], 
                          parameters = ["mass_1_source", "mass_2_source", "luminosity_distance", "v_p"],
                                labels = ['1', '2','3', '4','5'],
#                                 evidences=True,
                                bins=50, 
                                smooth=0.9, 
                                label_kwargs=dict(fontsize=12),
                                show_titles=True,    
                                title_kwargs=dict(fontsize=12), 
#                                 color='#0072C1',
#                                 truth_color='tab:orange', 
                                quantiles=[0.05, 0.95],
#                                 quantiles=[0.16, 0.84],
            #                     levels=(1 - np.exp(-0.5), 1 - np.exp(-2), 1 - np.exp(-9 / 2.)),
                                levels=(0.5,0.9),
                                plot_density=True, 
                                plot_datapoints=False, 
                                fill_contours=False,
                                max_n_ticks=3, hist_kwargs=dict(density=True), truths = [ None])

# %%
result_list =  bilby.core.result.ResultList([result11, result12, result13, result14, result15])
result_all = result_list.combine()

bilby.core.result.plot_multiple([result_all], 
                          parameters = ["mass_1_source", "mass_2_source", "luminosity_distance", "v_p"],
                                labels = ['combined'],
#                                 evidences=True,
                                bins=50, 
                                smooth=0.9, 
                                label_kwargs=dict(fontsize=12),
                                show_titles=True,    
                                title_kwargs=dict(fontsize=12), 
#                                 color='#0072C1',
#                                 truth_color='tab:orange', 
                                quantiles=[0.05, 0.95],
#                                 quantiles=[0.16, 0.84],
            #                     levels=(1 - np.exp(-0.5), 1 - np.exp(-2), 1 - np.exp(-9 / 2.)),
                                levels=(0.5,0.9),
                                plot_density=True, 
                                plot_datapoints=False, 
                                fill_contours=False,
                                max_n_ticks=3, hist_kwargs=dict(density=True), truths = [ None])

# result11.save_to_file(filename= 'test.hdf5', overwrite=True, outdir='.', extension='hdf5')
# Out:
# 11:22 bilby INFO    : Combined results have 107985 samples

# %%
#LIGO result - overall result (contain several pipline's result)

label = 'GW150914'

# if you do not have wget installed, simply download manually 
# https://dcc.ligo.org/LIGO-P1800370/public/GW150914_GWTC-1.hdf5 
# from your browser
# ! wget https://dcc.ligo.org/LIGO-P1800370/public/{label}_GWTC-1.hdf5

posterior_file = './'+label+'_GWTC-1.hdf5'

posterior = h5py.File(posterior_file, 'r')

print(posterior['IMRPhenomPv2_posterior'].dtype.names)

samples=pd.DataFrame.from_records(np.array(posterior['IMRPhenomPv2_posterior']))


z = np.array([z_at_value(Planck15.luminosity_distance, dist * u.Mpc) for dist in samples['luminosity_distance_Mpc']])

samples['m1_source_frame_Msun']=samples['m1_detector_frame_Msun']/(1.0+z)
samples['m2_source_frame_Msun']=samples['m2_detector_frame_Msun']/(1.0+z)
samples['redshift']=z

corner.corner(samples[['m1_source_frame_Msun','m2_source_frame_Msun','luminosity_distance_Mpc']],
              labels=['mass_1_source', 'mass_2_source','luminosity_distance',],
              bins=50, 
              smooth=0.9, 
              label_kwargs=dict(fontsize=12),
              show_titles=True,    
              title_kwargs=dict(fontsize=12), 
              color='#0072C1',
#             truth_color='tab:orange', 
              quantiles=[0.05, 0.95],
#             quantiles=[0.16, 0.84],
#              levels=(1 - np.exp(-0.5), 1 - np.exp(-2), 1 - np.exp(-9 / 2.)),
              levels=(0.5,0.9),
              plot_density=True, 
              plot_datapoints=False, 
              fill_contours=False,
              max_n_ticks=3,
              hist_kwargs=dict(density=True),
              truths = [ None, None, None]
             )
# Out:
# ('costheta_jn', 'luminosity_distance_Mpc', 'right_ascension', 'declination', 'm1_detector_frame_Msun', 'm2_detector_frame_Msun', 'spin1', 'spin2', 'costilt1', 'costilt2')
# WARNING:root:Pandas support in corner is deprecated; use ArviZ directly

# %%
print(posterior['Overall_posterior'].dtype.names)

samples=pd.DataFrame.from_records(np.array(posterior['Overall_posterior']))



z = np.array([z_at_value(Planck15.luminosity_distance, dist * u.Mpc) for dist in samples['luminosity_distance_Mpc']])

samples['m1_source_frame_Msun']=samples['m1_detector_frame_Msun']/(1.0+z)
samples['m2_source_frame_Msun']=samples['m2_detector_frame_Msun']/(1.0+z)
samples['redshift']=z

corner.corner(samples[['m1_source_frame_Msun','m2_source_frame_Msun','luminosity_distance_Mpc']],
              labels=['mass_1_source', 'mass_2_source','luminosity_distance',],
              bins=50, 
              smooth=0.9, 
              label_kwargs=dict(fontsize=12),
              show_titles=True,    
              title_kwargs=dict(fontsize=12), 
              color='#0072C1',
#             truth_color='tab:orange', 
              quantiles=[0.05, 0.95],
#             quantiles=[0.16, 0.84],
#              levels=(1 - np.exp(-0.5), 1 - np.exp(-2), 1 - np.exp(-9 / 2.)),
              levels=(0.5,0.9),
              plot_density=True, 
              plot_datapoints=False, 
              fill_contours=False,
              max_n_ticks=3,
              hist_kwargs=dict(density=True),
              truths = [ None, None, None]
             )
# Out:
# ('costheta_jn', 'luminosity_distance_Mpc', 'right_ascension', 'declination', 'm1_detector_frame_Msun', 'm2_detector_frame_Msun', 'spin1', 'spin2', 'costilt1', 'costilt2')
# WARNING:root:Pandas support in corner is deprecated; use ArviZ directly

# %% [markdown]
# ### broad priors

# %% [markdown]
# #### GW150914

# %%
# Group Server
path = "/run/user/1000/gvfs/sftp:host=119.78.226.26/share/home/yangsc/Documents/PE_3body/results_202308100349/GW150914_"

result11 = bilby.result.read_in_result(filename = path + '28' + '/GW150914_result.json')#1000 
result12 = bilby.result.read_in_result(filename = path + '5' + '/GW150914_result.json')#1000 
result13 = bilby.result.read_in_result(filename = path + '4' + '/GW150914_result.json')#1000 
result14 = bilby.result.read_in_result(filename = path + '97' + '/GW150914_result.json')#1000 

try:
    bilby.core.result.plot_multiple([result11, result12, result13, result14], 
                          parameters = ["mass_1_source", "mass_2_source", "luminosity_distance", ],
                                labels = ['1', '2','3', '4'],
#                                 evidences=True,
                                bins=50, 
                                smooth=0.9, 
                                label_kwargs=dict(fontsize=12),
                                show_titles=True,    
                                title_kwargs=dict(fontsize=12), 
#                                 color='#0072C1',
#                                 truth_color='tab:orange', 
                                quantiles=[0.05, 0.95],
#                                 quantiles=[0.16, 0.84],
            #                     levels=(1 - np.exp(-0.5), 1 - np.exp(-2), 1 - np.exp(-9 / 2.)),
                                levels=(0.5,0.9),
                                plot_density=True, 
                                plot_datapoints=False, 
                                fill_contours=False,
                                max_n_ticks=3, hist_kwargs=dict(density=True), truths = [ None])
except Exception as e:
    pass

# %%
result_list =  bilby.core.result.ResultList([result11, result12, result13, result14])
result_all = result_list.combine()

try:
    bilby.core.result.plot_multiple([result_all], 
                          parameters = ["mass_1_source", "mass_2_source", "luminosity_distance", ],
                                labels = ['combined'],
#                                 evidences=True,
                                bins=50, 
                                smooth=0.9, 
                                label_kwargs=dict(fontsize=12),
                                show_titles=True,    
                                title_kwargs=dict(fontsize=12), 
#                                 color='#0072C1',
#                                 truth_color='tab:orange', 
                                quantiles=[0.05, 0.95],
#                                 quantiles=[0.16, 0.84],
            #                     levels=(1 - np.exp(-0.5), 1 - np.exp(-2), 1 - np.exp(-9 / 2.)),
                                levels=(0.5,0.9),
                                plot_density=True, 
                                plot_datapoints=False, 
                                fill_contours=False,
                                max_n_ticks=3, hist_kwargs=dict(density=True), truths = [ None])

except Exception as e:
    pass

# result11.save_to_file(filename= 'test.hdf5', overwrite=True, outdir='.', extension='hdf5')
# Out:
# 13:33 bilby INFO    : Combined results have 129772 samples

# %% [markdown]
# #### GW151012

# %%
# Group Server
path = "/run/user/1000/gvfs/sftp:host=119.78.226.26/share/home/yangsc/Documents/PE_3body/results_202308100349/GW151012_"

result11 = bilby.result.read_in_result(filename = path + '1' + '/GW151012_result.json')#1000 
result12 = bilby.result.read_in_result(filename = path + '49' + '/GW151012_result.json')#1000 
result13 = bilby.result.read_in_result(filename = path + '92' + '/GW151012_result.json')#1000 
result14 = bilby.result.read_in_result(filename = path + '44' + '/GW151012_result.json')#1000 
result15 = bilby.result.read_in_result(filename = path + '53' + '/GW151012_result.json')#1000 

try:
    bilby.core.result.plot_multiple([result11, result12, result13, result14, result15], 
                          parameters = ["mass_1_source", "mass_2_source", "luminosity_distance", ],
                                labels = ['1', '2','3', '4', '5'],
#                                 evidences=True,
                                bins=50, 
                                smooth=0.9, 
                                label_kwargs=dict(fontsize=12),
                                show_titles=True,    
                                title_kwargs=dict(fontsize=12), 
#                                 color='#0072C1',
#                                 truth_color='tab:orange', 
                                quantiles=[0.05, 0.95],
#                                 quantiles=[0.16, 0.84],
            #                     levels=(1 - np.exp(-0.5), 1 - np.exp(-2), 1 - np.exp(-9 / 2.)),
                                levels=(0.5,0.9),
                                plot_density=True, 
                                plot_datapoints=False, 
                                fill_contours=False,
                                max_n_ticks=3, hist_kwargs=dict(density=True), truths = [ None])
except Exception as e:
    pass

# %%
result_list =  bilby.core.result.ResultList([result11, result12, result13, result14, result15])
result_all = result_list.combine()

try:
    bilby.core.result.plot_multiple([result_all], 
                          parameters = ["mass_1_source", "mass_2_source", "luminosity_distance", ],
                                labels = ['combined'],
#                                 evidences=True,
                                bins=50, 
                                smooth=0.9, 
                                label_kwargs=dict(fontsize=12),
                                show_titles=True,    
                                title_kwargs=dict(fontsize=12), 
#                                 color='#0072C1',
#                                 truth_color='tab:orange', 
                                quantiles=[0.05, 0.95],
#                                 quantiles=[0.16, 0.84],
            #                     levels=(1 - np.exp(-0.5), 1 - np.exp(-2), 1 - np.exp(-9 / 2.)),
                                levels=(0.5,0.9),
                                plot_density=True, 
                                plot_datapoints=False, 
                                fill_contours=False,
                                max_n_ticks=3, hist_kwargs=dict(density=True), truths = [ None])

except Exception as e:
    pass

# result11.save_to_file(filename= 'test.hdf5', overwrite=True, outdir='.', extension='hdf5')
# Out:
# 13:39 bilby INFO    : Combined results have 98964 samples

# %%
#LIGO result - overall result (contain several pipline's result)

label = 'GW151012'

# if you do not have wget installed, simply download manually 
# https://dcc.ligo.org/LIGO-P1800370/public/GW150914_GWTC-1.hdf5 
# from your browser
# ! wget https://dcc.ligo.org/LIGO-P1800370/public/{label}_GWTC-1.hdf5

posterior_file = './'+label+'_GWTC-1.hdf5'

posterior = h5py.File(posterior_file, 'r')

print(posterior['IMRPhenomPv2_posterior'].dtype.names)

samples=pd.DataFrame.from_records(np.array(posterior['IMRPhenomPv2_posterior']))


z = np.array([z_at_value(Planck15.luminosity_distance, dist * u.Mpc) for dist in samples['luminosity_distance_Mpc']])

samples['m1_source_frame_Msun']=samples['m1_detector_frame_Msun']/(1.0+z)
samples['m2_source_frame_Msun']=samples['m2_detector_frame_Msun']/(1.0+z)
samples['redshift']=z

corner.corner(samples[['m1_source_frame_Msun','m2_source_frame_Msun','luminosity_distance_Mpc']],
              labels=['mass_1_source', 'mass_2_source','luminosity_distance',],
              bins=50, 
              smooth=0.9, 
              label_kwargs=dict(fontsize=12),
              show_titles=True,    
              title_kwargs=dict(fontsize=12), 
              color='#0072C1',
#             truth_color='tab:orange', 
              quantiles=[0.05, 0.95],
#             quantiles=[0.16, 0.84],
#              levels=(1 - np.exp(-0.5), 1 - np.exp(-2), 1 - np.exp(-9 / 2.)),
              levels=(0.5,0.9),
              plot_density=True, 
              plot_datapoints=False, 
              fill_contours=False,
              max_n_ticks=3,
              hist_kwargs=dict(density=True),
              truths = [ None, None, None]
             )
# Out:
# ('costheta_jn', 'luminosity_distance_Mpc', 'right_ascension', 'declination', 'm1_detector_frame_Msun', 'm2_detector_frame_Msun', 'spin1', 'spin2', 'costilt1', 'costilt2')
# WARNING:root:Pandas support in corner is deprecated; use ArviZ directly

# %% [markdown]
# ### modified

# %%
# Group Server
path = "/run/user/1000/gvfs/sftp:host=119.78.226.66/home/ysc/Documents/PE_3body/results_202308150213/GW151012_"

result11 = bilby.result.read_in_result(filename = path + '14' + '/GW151012_result.json')#1000 
result12 = bilby.result.read_in_result(filename = path + '30' + '/GW151012_result.json')#1000 
result13 = bilby.result.read_in_result(filename = path + '36' + '/GW151012_result.json')#1000 
result14 = bilby.result.read_in_result(filename = path + '42' + '/GW151012_result.json')#1000 
result15 = bilby.result.read_in_result(filename = path + '6' + '/GW151012_result.json' )#1000 

bilby.core.result.plot_multiple([result11, result12, result13, result14, result15], 
                          parameters = ["mass_1_source", "mass_2_source", "luminosity_distance"],
                                labels = ['1', '2','3', '4','5'],
#                                 evidences=True,
                                bins=50, 
                                smooth=0.9, 
                                label_kwargs=dict(fontsize=12),
                                show_titles=True,    
                                title_kwargs=dict(fontsize=12), 
#                                 color='#0072C1',
#                                 truth_color='tab:orange', 
                                quantiles=[0.05, 0.95],
#                                 quantiles=[0.16, 0.84],
            #                     levels=(1 - np.exp(-0.5), 1 - np.exp(-2), 1 - np.exp(-9 / 2.)),
                                levels=(0.5,0.9),
                                plot_density=True, 
                                plot_datapoints=False, 
                                fill_contours=False,
                                max_n_ticks=3, hist_kwargs=dict(density=True), truths = [ None])
